# %%
import tensorflow as tf
from datetime import datetime
import os

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Dropout, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# %%
# Avoid Out Of Memory (OOM) errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)

for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tokenizer = Tokenizer()
data = open('../LSTM/irish-lyrics-eof.txt').read()

# corpus data normalized -> lower, split into strings by new line characters
c_data = data.lower().split("\n")

# fit the corpus data to the tokenizer
tokenizer.fit_on_texts(c_data)

# observe that we no longer use OOV instead we use +1
total_words = len(tokenizer.word_index) + 1

print(tokenizer.word_index)
print(total_words)
# Out:
# {'the': 1, 'and': 2, 'i': 3, 'to': 4, 'a': 5, 'of': 6, 'my': 7, 'in': 8, 'me': 9, 'for': 10, 'you': 11, 'all': 12, 'was': 13, 'she': 14, 'that': 15, 'on': 16, 'with': 17, 'her': 18, 'but': 19, 'as': 20, 'when': 21, 'love': 22, 'is': 23, 'your': 24, 'it': 25, 'will': 26, 'from': 27, 'by': 28, 'they': 29, 'be': 30, 'are': 31, 'so': 32, 'he': 33, 'old': 34, 'no': 35, 'oh': 36, 'ill': 37, 'at': 38, 'one': 39, 'his': 40, 'there': 41, 'were': 42, 'heart': 43, 'down': 44, 'now': 45, 'we': 46, 'where': 47, 'young': 48, 'never': 49, 'go': 50, 'come': 51, 'then': 52, 'did': 53, 'not': 54, 'said': 55, 'away': 56, 'their': 57, 'sweet': 58, 'them': 59, 'green': 60, 'if': 61, 'take': 62, 'our': 63, 'like': 64, 'night': 65, 'day': 66, 'o': 67, 'out': 68, 'fair': 69, 'this': 70, 'town': 71, 'have': 72, 'can': 73, 'true': 74, 'its': 75, 'thou': 76, 'see': 77, 'dear': 78, 'more': 79, 'theres': 80, 'or': 81, 'had': 82, 'would': 83, 'over': 84, 'hear': 85, 'up': 86, 'ive': 87, 'through': 88, 'home': 89, 'again': 90, 'well': 91, 'oer': 92, 'land': 93, 'good': 94, 'im': 95, 'ye': 96, 'sea': 97, 'left': 98, 'still': 99, 'father': 100, 'long': 101, 'rose': 102, 'could': 103, 'morning': 104, 'wild': 105, 'who': 106, 'eyes': 107, 'came': 108, 'while': 109, 'too': 110, 'back': 111, 'little': 112, 'an': 113, 'took': 114, 'him': 115, 'bow': 116, 'first': 117, 'let': 118, 'man': 119, 'shall': 120, 'know': 121, 'get': 122, 'high': 123, 'gone': 124, 'say': 125, 'ever': 126, 'some': 127, 'mary': 128, 'hand': 129, 'till': 130, 'put': 131, 'own': 132, 'time': 133, 'heard': 134, 'dead': 135, 'may': 136, 'bright': 137, 'mountain': 138, 'early': 139, 'rosin': 140, 'gave': 141, 'thee': 142, 'only': 143, 'far': 144, 'maid': 145, 'must': 146, 'find': 147, 'girl': 148, 'sure': 149, 'round': 150, 'dublin': 151, 'once': 152, 'world': 153, 'delight': 154, 'last': 155, 'johnny': 156, 'seen': 157, 'has': 158, 'fine': 159, 'road': 160, 'mother': 161, 'tis': 162, 'what': 163, 'way': 164, 'moon': 165, 'soul': 166, 'neer': 167, 'id': 168, 'just': 169, 'thats': 170, 'days': 171, 'darling': 172, 'went': 173, 'white': 174, 'die': 175, 'than': 176, 'hair': 177, 'goes': 178, 'meet': 179, 'today': 180, 'do': 181, 'girls': 182, 'shes': 183, 'thyme': 184, 'thy': 185, 'sing': 186, 'pretty': 187, 'new': 188, 'poor': 189, 'into': 190, 'life': 191, 'irish': 192, 'give': 193, 'boy': 194, 'youre': 195, 'make': 196, 'passed': 197, 'lovely': 198, 'black': 199, 'youll': 200, 'died': 201, 'red': 202, 'smile': 203, 'keep': 204, 'loves': 205, 'free': 206, 'leave': 207, 'friends': 208, 'each': 209, 'saw': 210, 'behind': 211, 'song': 212, 'ra': 213, 'dont': 214, 'arms': 215, 'am': 216, 'sun': 217, 'saying': 218, 'made': 219, 'wish': 220, 'cold': 221, 'met': 222, 'before': 223, 'should': 224, 'rocky': 225, 'light': 226, 'wid': 227, 'boys': 228, 'best': 229, 'fields': 230, 'since': 231, 'ball': 232, 'water': 233, 'casey': 234, 'mind': 235, 'along': 236, 'loved': 237, 'place': 238, 'ireland': 239, 'next': 240, 'three': 241, 'many': 242, 'years': 243, 'door': 244, 'us': 245, 'drink': 246, 'got': 247, 'might': 248, 'live': 249, 'roses': 250, 'play': 251, 'soon': 252, 'ground': 253, 'times': 254, 'spent': 255, 'going': 256, 'tree': 257, 'barley': 258, 'grass': 259, 'kind': 260, 'twas': 261, 'bridge': 262, 'around': 263, 'blue': 264, 'tell': 265, 'row': 266, 'how': 267, 'money': 268, 'merry': 269, 'stepped': 270, 'corporal': 271, 'always': 272, 'though': 273, 'near': 274, 'taken': 275, 'ones': 276, 'daughter': 277, 'forever': 278, 'loo': 279, 'shining': 280, 'plenty': 281, 'hes': 282, 'ship': 283, 'banks': 284, 'think': 285, 'very': 286, 'stand': 287, 'heres': 288, 'snow': 289, 'mountains': 290, 'molly': 291, 'wheel': 292, 'street': 293, 'erin': 294, 'side': 295, 'feet': 296, 'star': 297, 'look': 298, 'brave': 299, 'woman': 300, 'sons': 301, 'two': 302, 'says': 303, 'asked': 304, 'lanigans': 305, 'singing': 306, 'men': 307, 'toome': 308, 'stole': 309, 'god': 310, 'hill': 311, 'lonely': 312, 'lover': 313,  ...
# 2690

# %%
input_sequences = []

for line in c_data:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# pad sequences
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences,
                                         maxlen=max_sequence_len,
                                         padding='pre'))

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
xs, labels = input_sequences[:, :-1], input_sequences[:, -1]
ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)
x_train, x_val, y_train, y_val = train_test_split(xs, ys, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Embedding(total_words, 200, input_length=max_sequence_len-1))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(512, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dense(total_words, activation='softmax'))

model.compile('adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 15, 200)           538000
#
#  lstm (LSTM)                 (None, 15, 256)           467968
#
#  dropout (Dropout)           (None, 15, 256)           0
#
#  lstm_1 (LSTM)               (None, 15, 512)           1574912
#
#  dropout_1 (Dropout)         (None, 15, 512)           0
#
#  lstm_2 (LSTM)               (None, 256)               787456
#
#  dense (Dense)               (None, 2690)              691330
#
# =================================================================
# Total params: 4,059,666
# Trainable params: 4,059,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
epochs = 1000

history = model.fit(xs, ys, epochs=epochs, validation_data=(
    x_val, y_val), verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 377/377 [==============================] - 13s 22ms/step - loss: 6.8059 - accuracy: 0.0640 - val_loss: 6.3384 - val_accuracy: 0.0673
# Epoch 2/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 6.4912 - accuracy: 0.0657 - val_loss: 6.3326 - val_accuracy: 0.0673
# Epoch 3/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 6.4019 - accuracy: 0.0657 - val_loss: 6.1833 - val_accuracy: 0.0673
# Epoch 4/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 6.2681 - accuracy: 0.0695 - val_loss: 6.0347 - val_accuracy: 0.0781
# Epoch 5/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 6.1083 - accuracy: 0.0768 - val_loss: 5.8694 - val_accuracy: 0.0909
# Epoch 6/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 5.9413 - accuracy: 0.0799 - val_loss: 5.7221 - val_accuracy: 0.0855
# Epoch 7/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 5.8043 - accuracy: 0.0815 - val_loss: 5.5966 - val_accuracy: 0.0934
# Epoch 8/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 5.6755 - accuracy: 0.0861 - val_loss: 5.4729 - val_accuracy: 0.0951
# Epoch 9/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 5.5587 - accuracy: 0.0904 - val_loss: 5.3707 - val_accuracy: 0.0918
# Epoch 10/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 5.4420 - accuracy: 0.0951 - val_loss: 5.2172 - val_accuracy: 0.1038
# Epoch 11/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 5.3149 - accuracy: 0.0981 - val_loss: 5.1138 - val_accuracy: 0.1067
# Epoch 12/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 5.1859 - accuracy: 0.1057 - val_loss: 4.9589 - val_accuracy: 0.1208
# Epoch 13/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 5.0615 - accuracy: 0.1103 - val_loss: 4.8277 - val_accuracy: 0.1242
# Epoch 14/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 4.9371 - accuracy: 0.1218 - val_loss: 4.6994 - val_accuracy: 0.1333
# Epoch 15/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 4.8008 - accuracy: 0.1318 - val_loss: 4.5521 - val_accuracy: 0.1503
# Epoch 16/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 4.6707 - accuracy: 0.1393 - val_loss: 4.4254 - val_accuracy: 0.1591
# Epoch 17/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 4.5370 - accuracy: 0.1459 - val_loss: 4.2569 - val_accuracy: 0.1620
# Epoch 18/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 4.3878 - accuracy: 0.1563 - val_loss: 4.1425 - val_accuracy: 0.1757
# Epoch 19/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 4.2425 - accuracy: 0.1666 - val_loss: 3.9684 - val_accuracy: 0.1981
# Epoch 20/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 4.0943 - accuracy: 0.1760 - val_loss: 3.8159 - val_accuracy: 0.2097
# Epoch 21/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 3.9576 - accuracy: 0.1920 - val_loss: 3.6684 - val_accuracy: 0.2392
# Epoch 22/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 3.8232 - accuracy: 0.2044 - val_loss: 3.5232 - val_accuracy: 0.2658
# Epoch 23/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 3.6977 - accuracy: 0.2242 - val_loss: 3.3919 - val_accuracy: 0.2899
# Epoch 24/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 3.5717 - accuracy: 0.2392 - val_loss: 3.2573 - val_accuracy: 0.3090
# Epoch 25/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 3.4459 - accuracy: 0.2579 - val_loss: 3.1482 - val_accuracy: 0.3148
# Epoch 26/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 3.3285 - accuracy: 0.2740 - val_loss: 3.0336 - val_accuracy: 0.3559
# Epoch 27/1000
# 377/377 [==============================] - 7s 20ms/step - loss: 3.2157 - accuracy: 0.2927 - val_loss: 2.9002 - val_accuracy: 0.3808
# Epoch 28/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 3.1009 - accuracy: 0.3148 - val_loss: 2.7730 - val_accuracy: 0.4024
# Epoch 29/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.9812 - accuracy: 0.3383 - val_loss: 2.6722 - val_accuracy: 0.4257
# Epoch 30/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.8759 - accuracy: 0.3582 - val_loss: 2.5653 - val_accuracy: 0.4460
# Epoch 31/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.7835 - accuracy: 0.3733 - val_loss: 2.4858 - val_accuracy: 0.4576
# Epoch 32/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.6679 - accuracy: 0.3977 - val_loss: 2.3662 - val_accuracy: 0.4788
# Epoch 33/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 2.5762 - accuracy: 0.4158 - val_loss: 2.2628 - val_accuracy: 0.5054
# Epoch 34/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.4737 - accuracy: 0.4355 - val_loss: 2.1569 - val_accuracy: 0.5241
# Epoch 35/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.3855 - accuracy: 0.4564 - val_loss: 2.0908 - val_accuracy: 0.5324
# Epoch 36/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 2.2929 - accuracy: 0.4718 - val_loss: 1.9874 - val_accuracy: 0.5552
# Epoch 37/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 2.2093 - accuracy: 0.4940 - val_loss: 1.9106 - val_accuracy: 0.5768
# Epoch 38/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.1283 - accuracy: 0.5095 - val_loss: 1.8224 - val_accuracy: 0.6026
# Epoch 39/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 2.0504 - accuracy: 0.5264 - val_loss: 1.7679 - val_accuracy: 0.6071
# Epoch 40/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.9738 - accuracy: 0.5425 - val_loss: 1.6690 - val_accuracy: 0.6300
# Epoch 41/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.8964 - accuracy: 0.5612 - val_loss: 1.6098 - val_accuracy: 0.6474
# Epoch 42/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.8276 - accuracy: 0.5785 - val_loss: 1.5377 - val_accuracy: 0.6665
# Epoch 43/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.7593 - accuracy: 0.5936 - val_loss: 1.4978 - val_accuracy: 0.6773
# Epoch 44/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.7039 - accuracy: 0.6042 - val_loss: 1.4197 - val_accuracy: 0.6977
# Epoch 45/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 1.6435 - accuracy: 0.6186 - val_loss: 1.3484 - val_accuracy: 0.7064
# Epoch 46/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 1.5798 - accuracy: 0.6298 - val_loss: 1.2861 - val_accuracy: 0.7301
# Epoch 47/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.5305 - accuracy: 0.6397 - val_loss: 1.2505 - val_accuracy: 0.7330
# Epoch 48/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 1.4707 - accuracy: 0.6578 - val_loss: 1.1878 - val_accuracy: 0.7492
# Epoch 49/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 1.4197 - accuracy: 0.6720 - val_loss: 1.1433 - val_accuracy: 0.7583
# Epoch 50/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 1.3644 - accuracy: 0.6819 - val_loss: 1.1169 - val_accuracy: 0.7604
# Epoch 51/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.3248 - accuracy: 0.6885 - val_loss: 1.0577 - val_accuracy: 0.7799
# Epoch 52/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.2784 - accuracy: 0.7058 - val_loss: 1.0362 - val_accuracy: 0.7749
# Epoch 53/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.2378 - accuracy: 0.7132 - val_loss: 1.0153 - val_accuracy: 0.7886
# Epoch 54/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.2034 - accuracy: 0.7256 - val_loss: 0.9561 - val_accuracy: 0.7990
# Epoch 55/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.1640 - accuracy: 0.7283 - val_loss: 0.9124 - val_accuracy: 0.8065
# Epoch 56/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 1.1171 - accuracy: 0.7407 - val_loss: 0.8767 - val_accuracy: 0.8131
# Epoch 57/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.0852 - accuracy: 0.7478 - val_loss: 0.8480 - val_accuracy: 0.8198
# Epoch 58/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.0701 - accuracy: 0.7520 - val_loss: 0.8370 - val_accuracy: 0.8194
# Epoch 59/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 1.0351 - accuracy: 0.7574 - val_loss: 0.8017 - val_accuracy: 0.8272
# Epoch 60/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.9981 - accuracy: 0.7698 - val_loss: 0.7750 - val_accuracy: 0.8293
# Epoch 61/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.9602 - accuracy: 0.7770 - val_loss: 0.7507 - val_accuracy: 0.8355
# Epoch 62/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.9468 - accuracy: 0.7780 - val_loss: 0.7266 - val_accuracy: 0.8405
# Epoch 63/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.9201 - accuracy: 0.7871 - val_loss: 0.7061 - val_accuracy: 0.8443
# Epoch 64/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.8918 - accuracy: 0.7941 - val_loss: 0.6858 - val_accuracy: 0.8434
# Epoch 65/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 0.8631 - accuracy: 0.7993 - val_loss: 0.6685 - val_accuracy: 0.8484
# Epoch 66/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 0.8519 - accuracy: 0.8005 - val_loss: 0.6486 - val_accuracy: 0.8567
# Epoch 67/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.8320 - accuracy: 0.8043 - val_loss: 0.6443 - val_accuracy: 0.8509
# Epoch 68/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.8155 - accuracy: 0.8099 - val_loss: 0.6296 - val_accuracy: 0.8509
# Epoch 69/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.7981 - accuracy: 0.8101 - val_loss: 0.6155 - val_accuracy: 0.8559
# Epoch 70/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.7805 - accuracy: 0.8145 - val_loss: 0.6044 - val_accuracy: 0.8542
# Epoch 71/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.7676 - accuracy: 0.8168 - val_loss: 0.5887 - val_accuracy: 0.8596
# Epoch 72/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.7475 - accuracy: 0.8203 - val_loss: 0.5744 - val_accuracy: 0.8630
# Epoch 73/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 0.7317 - accuracy: 0.8235 - val_loss: 0.5603 - val_accuracy: 0.8646
# Epoch 74/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.7148 - accuracy: 0.8266 - val_loss: 0.5583 - val_accuracy: 0.8688
# Epoch 75/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.7114 - accuracy: 0.8270 - val_loss: 0.5495 - val_accuracy: 0.8596
# Epoch 76/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.7009 - accuracy: 0.8297 - val_loss: 0.5417 - val_accuracy: 0.8630
# Epoch 77/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.6911 - accuracy: 0.8298 - val_loss: 0.5375 - val_accuracy: 0.8663
# Epoch 78/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.6876 - accuracy: 0.8285 - val_loss: 0.5192 - val_accuracy: 0.8746
# Epoch 79/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.6662 - accuracy: 0.8349 - val_loss: 0.5180 - val_accuracy: 0.8721
# Epoch 80/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.6484 - accuracy: 0.8389 - val_loss: 0.5085 - val_accuracy: 0.8684
# Epoch 81/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.6507 - accuracy: 0.8376 - val_loss: 0.5078 - val_accuracy: 0.8688
# Epoch 82/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.6510 - accuracy: 0.8347 - val_loss: 0.5096 - val_accuracy: 0.8667
# Epoch 83/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.6376 - accuracy: 0.8388 - val_loss: 0.5003 - val_accuracy: 0.8679
# Epoch 84/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.6266 - accuracy: 0.8411 - val_loss: 0.4952 - val_accuracy: 0.8708
# Epoch 85/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.6296 - accuracy: 0.8374 - val_loss: 0.4831 - val_accuracy: 0.8708
# Epoch 86/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.6189 - accuracy: 0.8393 - val_loss: 0.4831 - val_accuracy: 0.8721
# Epoch 87/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.6156 - accuracy: 0.8391 - val_loss: 0.4713 - val_accuracy: 0.8713
# Epoch 88/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.6042 - accuracy: 0.8413 - val_loss: 0.4763 - val_accuracy: 0.8708
# Epoch 89/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.5953 - accuracy: 0.8437 - val_loss: 0.4779 - val_accuracy: 0.8708
# Epoch 90/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.5895 - accuracy: 0.8457 - val_loss: 0.4660 - val_accuracy: 0.8742
# Epoch 91/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.5916 - accuracy: 0.8432 - val_loss: 0.4665 - val_accuracy: 0.8725
# Epoch 92/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.5874 - accuracy: 0.8446 - val_loss: 0.4626 - val_accuracy: 0.8725
# Epoch 93/1000
# 377/377 [==============================] - 7s 19ms/step - loss: 0.5791 - accuracy: 0.8463 - val_loss: 0.4625 - val_accuracy: 0.8696
# Epoch 94/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.5741 - accuracy: 0.8454 - val_loss: 0.4593 - val_accuracy: 0.8733
# Epoch 95/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 0.5708 - accuracy: 0.8454 - val_loss: 0.4556 - val_accuracy: 0.8754
# Epoch 96/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.5701 - accuracy: 0.8457 - val_loss: 0.4498 - val_accuracy: 0.8733
# Epoch 97/1000
# 377/377 [==============================] - 7s 17ms/step - loss: 0.5651 - accuracy: 0.8464 - val_loss: 0.4436 - val_accuracy: 0.8742
# Epoch 98/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.5708 - accuracy: 0.8436 - val_loss: 0.4454 - val_accuracy: 0.8762
# Epoch 99/1000
# 377/377 [==============================] - 7s 18ms/step - loss: 0.5707 - accuracy: 0.8464 - val_loss: 0.4476 - val_accuracy: 0.8738
# Epoch 100/1000
# 377/377 [==============================] - 6s 17ms/step - loss: 0.5582 - accuracy: 0.8476 - val_loss: 0.4442 - val_accuracy: 0.8733

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
seed_text = "I've got a good feeling about this"
next_words = 20

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list],maxlen=max_sequence_len-1,padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word
print(seed_text)
# Out:
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# I've got a good feeling about this mountain day where the rose of tralee mad at love love love the be drown when the poor then found

# %%
# Define a unique model name based on the current timestamp
model_name = f'model_{str(datetime.now().strftime("%Y%m%d_%H%M%S"))}.h5'
model_path = os.path.join('LSTMModelsT', model_name)
# Save the trained model
model.save(model_path)
print(f"Trained model saved at: {model_path}")
# Out:
# Trained model saved at: LSTMModelsT\model_20230608_185915.h5

# %%
# Save the tokenizer with a unique filename
import pickle
tokenizer_file = f'tokenizer_{str(datetime.now().strftime("%Y%m%d_%H%M%S"))}.pkl'
os.makedirs('LSTM TokenizerT')
tokenizer_path = os.path.join('LSTM TokenizerT', tokenizer_file)

# Save the tokenizer
with open(tokenizer_path, 'wb') as f:
    pickle.dump(tokenizer, f)
print(f"Tokenizer saved at: {model_path}")
# Out:
# Tokenizer saved at: LSTMModelsT\model_20230608_185915.h5
