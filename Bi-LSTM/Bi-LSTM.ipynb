# %%
import tensorflow as tf
from datetime import datetime

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np
import os

# %%
# Avoid Out Of Memory (OOM) errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)

for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tokenizer = Tokenizer()
data = open('../LSTM/irish-lyrics-eof.txt').read()

# corpus data normalized -> lower, split into strings by new line characters
c_data = data.lower().split("\n")

# fit the corpus data to the tokenizer
tokenizer.fit_on_texts(c_data)

# observe that we no longer use OOV instead we use +1
total_words = len(tokenizer.word_index) + 1

print(tokenizer.word_index)
print(total_words)
# Out:
# {'the': 1, 'and': 2, 'i': 3, 'to': 4, 'a': 5, 'of': 6, 'my': 7, 'in': 8, 'me': 9, 'for': 10, 'you': 11, 'all': 12, 'was': 13, 'she': 14, 'that': 15, 'on': 16, 'with': 17, 'her': 18, 'but': 19, 'as': 20, 'when': 21, 'love': 22, 'is': 23, 'your': 24, 'it': 25, 'will': 26, 'from': 27, 'by': 28, 'they': 29, 'be': 30, 'are': 31, 'so': 32, 'he': 33, 'old': 34, 'no': 35, 'oh': 36, 'ill': 37, 'at': 38, 'one': 39, 'his': 40, 'there': 41, 'were': 42, 'heart': 43, 'down': 44, 'now': 45, 'we': 46, 'where': 47, 'young': 48, 'never': 49, 'go': 50, 'come': 51, 'then': 52, 'did': 53, 'not': 54, 'said': 55, 'away': 56, 'their': 57, 'sweet': 58, 'them': 59, 'green': 60, 'if': 61, 'take': 62, 'our': 63, 'like': 64, 'night': 65, 'day': 66, 'o': 67, 'out': 68, 'fair': 69, 'this': 70, 'town': 71, 'have': 72, 'can': 73, 'true': 74, 'its': 75, 'thou': 76, 'see': 77, 'dear': 78, 'more': 79, 'theres': 80, 'or': 81, 'had': 82, 'would': 83, 'over': 84, 'hear': 85, 'up': 86, 'ive': 87, 'through': 88, 'home': 89, 'again': 90, 'well': 91, 'oer': 92, 'land': 93, 'good': 94, 'im': 95, 'ye': 96, 'sea': 97, 'left': 98, 'still': 99, 'father': 100, 'long': 101, 'rose': 102, 'could': 103, 'morning': 104, 'wild': 105, 'who': 106, 'eyes': 107, 'came': 108, 'while': 109, 'too': 110, 'back': 111, 'little': 112, 'an': 113, 'took': 114, 'him': 115, 'bow': 116, 'first': 117, 'let': 118, 'man': 119, 'shall': 120, 'know': 121, 'get': 122, 'high': 123, 'gone': 124, 'say': 125, 'ever': 126, 'some': 127, 'mary': 128, 'hand': 129, 'till': 130, 'put': 131, 'own': 132, 'time': 133, 'heard': 134, 'dead': 135, 'may': 136, 'bright': 137, 'mountain': 138, 'early': 139, 'rosin': 140, 'gave': 141, 'thee': 142, 'only': 143, 'far': 144, 'maid': 145, 'must': 146, 'find': 147, 'girl': 148, 'sure': 149, 'round': 150, 'dublin': 151, 'once': 152, 'world': 153, 'delight': 154, 'last': 155, 'johnny': 156, 'seen': 157, 'has': 158, 'fine': 159, 'road': 160, 'mother': 161, 'tis': 162, 'what': 163, 'way': 164, 'moon': 165, 'soul': 166, 'neer': 167, 'id': 168, 'just': 169, 'thats': 170, 'days': 171, 'darling': 172, 'went': 173, 'white': 174, 'die': 175, 'than': 176, 'hair': 177, 'goes': 178, 'meet': 179, 'today': 180, 'do': 181, 'girls': 182, 'shes': 183, 'thyme': 184, 'thy': 185, 'sing': 186, 'pretty': 187, 'new': 188, 'poor': 189, 'into': 190, 'life': 191, 'irish': 192, 'give': 193, 'boy': 194, 'youre': 195, 'make': 196, 'passed': 197, 'lovely': 198, 'black': 199, 'youll': 200, 'died': 201, 'red': 202, 'smile': 203, 'keep': 204, 'loves': 205, 'free': 206, 'leave': 207, 'friends': 208, 'each': 209, 'saw': 210, 'behind': 211, 'song': 212, 'ra': 213, 'dont': 214, 'arms': 215, 'am': 216, 'sun': 217, 'saying': 218, 'made': 219, 'wish': 220, 'cold': 221, 'met': 222, 'before': 223, 'should': 224, 'rocky': 225, 'light': 226, 'wid': 227, 'boys': 228, 'best': 229, 'fields': 230, 'since': 231, 'ball': 232, 'water': 233, 'casey': 234, 'mind': 235, 'along': 236, 'loved': 237, 'place': 238, 'ireland': 239, 'next': 240, 'three': 241, 'many': 242, 'years': 243, 'door': 244, 'us': 245, 'drink': 246, 'got': 247, 'might': 248, 'live': 249, 'roses': 250, 'play': 251, 'soon': 252, 'ground': 253, 'times': 254, 'spent': 255, 'going': 256, 'tree': 257, 'barley': 258, 'grass': 259, 'kind': 260, 'twas': 261, 'bridge': 262, 'around': 263, 'blue': 264, 'tell': 265, 'row': 266, 'how': 267, 'money': 268, 'merry': 269, 'stepped': 270, 'corporal': 271, 'always': 272, 'though': 273, 'near': 274, 'taken': 275, 'ones': 276, 'daughter': 277, 'forever': 278, 'loo': 279, 'shining': 280, 'plenty': 281, 'hes': 282, 'ship': 283, 'banks': 284, 'think': 285, 'very': 286, 'stand': 287, 'heres': 288, 'snow': 289, 'mountains': 290, 'molly': 291, 'wheel': 292, 'street': 293, 'erin': 294, 'side': 295, 'feet': 296, 'star': 297, 'look': 298, 'brave': 299, 'woman': 300, 'sons': 301, 'two': 302, 'says': 303, 'asked': 304, 'lanigans': 305, 'singing': 306, 'men': 307, 'toome': 308, 'stole': 309, 'god': 310, 'hill': 311, 'lonely': 312, 'lover': 313,  ...
# 2690

# %%
input_sequences = []

for line in c_data:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# pad sequences
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences,
                                         maxlen=max_sequence_len,
                                         padding='pre'))

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and validation sets
xs, labels = input_sequences[:, :-1], input_sequences[:, -1]
ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)
x_train, x_val, y_train, y_val = train_test_split(xs, ys, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Embedding(total_words, 200, input_length=max_sequence_len-1))
model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(256, return_sequences=True)))
model.add(Bidirectional(LSTM(128, return_sequences=False)))
model.add(Dense(total_words, activation='softmax'))

model.compile('adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 15, 200)           538000
#
#  bidirectional (Bidirectiona  (None, 15, 512)          935936
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 15, 512)          1574912
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256)              656384
#  nal)
#
#  dense (Dense)               (None, 2690)              691330
#
# =================================================================
# Total params: 4,396,562
# Trainable params: 4,396,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3)
epochs = 1000

history = model.fit(xs, ys, epochs=epochs, validation_data=(
    x_val, y_val), verbose=1, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 377/377 [==============================] - 19s 28ms/step - loss: 6.7596 - accuracy: 0.0641 - val_loss: 6.2607 - val_accuracy: 0.0673
# Epoch 2/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 6.3490 - accuracy: 0.0660 - val_loss: 6.1022 - val_accuracy: 0.0739
# Epoch 3/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 6.1741 - accuracy: 0.0769 - val_loss: 5.9340 - val_accuracy: 0.0818
# Epoch 4/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 6.0035 - accuracy: 0.0838 - val_loss: 5.7509 - val_accuracy: 0.0988
# Epoch 5/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 5.8396 - accuracy: 0.0952 - val_loss: 5.6025 - val_accuracy: 0.1130
# Epoch 6/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 5.6828 - accuracy: 0.1088 - val_loss: 5.4532 - val_accuracy: 0.1184
# Epoch 7/1000
# 377/377 [==============================] - 10s 25ms/step - loss: 5.5368 - accuracy: 0.1169 - val_loss: 5.3215 - val_accuracy: 0.1254
# Epoch 8/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 5.4113 - accuracy: 0.1239 - val_loss: 5.1845 - val_accuracy: 0.1387
# Epoch 9/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 5.2880 - accuracy: 0.1295 - val_loss: 5.0565 - val_accuracy: 0.1453
# Epoch 10/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 5.1898 - accuracy: 0.1333 - val_loss: 4.9447 - val_accuracy: 0.1470
# Epoch 11/1000
# 377/377 [==============================] - 10s 25ms/step - loss: 5.0737 - accuracy: 0.1396 - val_loss: 4.8625 - val_accuracy: 0.1541
# Epoch 12/1000
# 377/377 [==============================] - 10s 25ms/step - loss: 4.9588 - accuracy: 0.1465 - val_loss: 4.7310 - val_accuracy: 0.1645
# Epoch 13/1000
# 377/377 [==============================] - 10s 25ms/step - loss: 4.8560 - accuracy: 0.1543 - val_loss: 4.6149 - val_accuracy: 0.1711
# Epoch 14/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 4.7391 - accuracy: 0.1603 - val_loss: 4.5201 - val_accuracy: 0.1744
# Epoch 15/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 4.6308 - accuracy: 0.1676 - val_loss: 4.4323 - val_accuracy: 0.1848
# Epoch 16/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 4.5301 - accuracy: 0.1735 - val_loss: 4.3089 - val_accuracy: 0.1865
# Epoch 17/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 4.4258 - accuracy: 0.1831 - val_loss: 4.2032 - val_accuracy: 0.1993
# Epoch 18/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 4.3128 - accuracy: 0.1909 - val_loss: 4.0858 - val_accuracy: 0.2089
# Epoch 19/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 4.1999 - accuracy: 0.2004 - val_loss: 3.9732 - val_accuracy: 0.2197
# Epoch 20/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 4.0931 - accuracy: 0.2084 - val_loss: 3.8561 - val_accuracy: 0.2367
# Epoch 21/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 3.9818 - accuracy: 0.2181 - val_loss: 3.7551 - val_accuracy: 0.2346
# Epoch 22/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 3.8607 - accuracy: 0.2306 - val_loss: 3.6269 - val_accuracy: 0.2525
# Epoch 23/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 3.7578 - accuracy: 0.2402 - val_loss: 3.5218 - val_accuracy: 0.2699
# Epoch 24/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 3.6432 - accuracy: 0.2515 - val_loss: 3.3777 - val_accuracy: 0.2865
# Epoch 25/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 3.5541 - accuracy: 0.2629 - val_loss: 3.3001 - val_accuracy: 0.3048
# Epoch 26/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 3.4129 - accuracy: 0.2852 - val_loss: 3.1869 - val_accuracy: 0.3281
# Epoch 27/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 3.3074 - accuracy: 0.3030 - val_loss: 3.0338 - val_accuracy: 0.3542
# Epoch 28/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 3.1733 - accuracy: 0.3205 - val_loss: 2.9391 - val_accuracy: 0.3654
# Epoch 29/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 3.0684 - accuracy: 0.3387 - val_loss: 2.8320 - val_accuracy: 0.3966
# Epoch 30/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 2.9528 - accuracy: 0.3628 - val_loss: 2.7326 - val_accuracy: 0.4111
# Epoch 31/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 2.8546 - accuracy: 0.3819 - val_loss: 2.6691 - val_accuracy: 0.4319
# Epoch 32/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 2.7556 - accuracy: 0.3998 - val_loss: 2.5143 - val_accuracy: 0.4626
# Epoch 33/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 2.6298 - accuracy: 0.4258 - val_loss: 2.4157 - val_accuracy: 0.4809
# Epoch 34/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 2.5487 - accuracy: 0.4393 - val_loss: 2.3224 - val_accuracy: 0.4884
# Epoch 35/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 2.4430 - accuracy: 0.4603 - val_loss: 2.1970 - val_accuracy: 0.5270
# Epoch 36/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 2.3319 - accuracy: 0.4870 - val_loss: 2.1080 - val_accuracy: 0.5523
# Epoch 37/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 2.2459 - accuracy: 0.5062 - val_loss: 2.0444 - val_accuracy: 0.5669
# Epoch 38/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 2.1608 - accuracy: 0.5202 - val_loss: 1.9618 - val_accuracy: 0.5772
# Epoch 39/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 2.0576 - accuracy: 0.5444 - val_loss: 1.8640 - val_accuracy: 0.5993
# Epoch 40/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.9603 - accuracy: 0.5684 - val_loss: 1.7751 - val_accuracy: 0.6096
# Epoch 41/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.8878 - accuracy: 0.5851 - val_loss: 1.6947 - val_accuracy: 0.6391
# Epoch 42/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 1.7900 - accuracy: 0.6041 - val_loss: 1.5899 - val_accuracy: 0.6599
# Epoch 43/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 1.7202 - accuracy: 0.6248 - val_loss: 1.5839 - val_accuracy: 0.6611
# Epoch 44/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.6805 - accuracy: 0.6261 - val_loss: 1.5644 - val_accuracy: 0.6603
# Epoch 45/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.6116 - accuracy: 0.6408 - val_loss: 1.4054 - val_accuracy: 0.6952
# Epoch 46/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.5057 - accuracy: 0.6684 - val_loss: 1.3254 - val_accuracy: 0.7168
# Epoch 47/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.4277 - accuracy: 0.6867 - val_loss: 1.2572 - val_accuracy: 0.7305
# Epoch 48/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.3740 - accuracy: 0.6955 - val_loss: 1.2405 - val_accuracy: 0.7326
# Epoch 49/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 1.3315 - accuracy: 0.7037 - val_loss: 1.2295 - val_accuracy: 0.7359
# Epoch 50/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.2791 - accuracy: 0.7146 - val_loss: 1.0969 - val_accuracy: 0.7699
# Epoch 51/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.1991 - accuracy: 0.7345 - val_loss: 1.0596 - val_accuracy: 0.7724
# Epoch 52/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 1.1435 - accuracy: 0.7450 - val_loss: 0.9874 - val_accuracy: 0.7857
# Epoch 53/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 1.0793 - accuracy: 0.7620 - val_loss: 0.9448 - val_accuracy: 0.8019
# Epoch 54/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 1.1716 - accuracy: 0.7341 - val_loss: 0.9878 - val_accuracy: 0.7836
# Epoch 55/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 1.0474 - accuracy: 0.7639 - val_loss: 0.8955 - val_accuracy: 0.8123
# Epoch 56/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.9682 - accuracy: 0.7830 - val_loss: 0.8445 - val_accuracy: 0.8202
# Epoch 57/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.9239 - accuracy: 0.7951 - val_loss: 0.8056 - val_accuracy: 0.8264
# Epoch 58/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 0.9365 - accuracy: 0.7897 - val_loss: 0.8040 - val_accuracy: 0.8239
# Epoch 59/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.9173 - accuracy: 0.7897 - val_loss: 0.7539 - val_accuracy: 0.8331
# Epoch 60/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.8417 - accuracy: 0.8060 - val_loss: 0.7179 - val_accuracy: 0.8459
# Epoch 61/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.8732 - accuracy: 0.7982 - val_loss: 0.8128 - val_accuracy: 0.8181
# Epoch 62/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.8457 - accuracy: 0.8059 - val_loss: 0.7053 - val_accuracy: 0.8426
# Epoch 63/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.7761 - accuracy: 0.8196 - val_loss: 0.6651 - val_accuracy: 0.8505
# Epoch 64/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.7307 - accuracy: 0.8295 - val_loss: 0.6238 - val_accuracy: 0.8592
# Epoch 65/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.7130 - accuracy: 0.8312 - val_loss: 0.6139 - val_accuracy: 0.8609
# Epoch 66/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6806 - accuracy: 0.8391 - val_loss: 0.6015 - val_accuracy: 0.8621
# Epoch 67/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6658 - accuracy: 0.8381 - val_loss: 0.5920 - val_accuracy: 0.8600
# Epoch 68/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6620 - accuracy: 0.8375 - val_loss: 0.5789 - val_accuracy: 0.8675
# Epoch 69/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6516 - accuracy: 0.8396 - val_loss: 0.5665 - val_accuracy: 0.8650
# Epoch 70/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6405 - accuracy: 0.8424 - val_loss: 0.5977 - val_accuracy: 0.8571
# Epoch 71/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6722 - accuracy: 0.8315 - val_loss: 0.5713 - val_accuracy: 0.8625
# Epoch 72/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 0.6485 - accuracy: 0.8379 - val_loss: 0.5491 - val_accuracy: 0.8700
# Epoch 73/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6328 - accuracy: 0.8406 - val_loss: 0.5371 - val_accuracy: 0.8638
# Epoch 74/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6055 - accuracy: 0.8425 - val_loss: 0.5424 - val_accuracy: 0.8630
# Epoch 75/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6000 - accuracy: 0.8438 - val_loss: 0.5390 - val_accuracy: 0.8630
# Epoch 76/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.5962 - accuracy: 0.8436 - val_loss: 0.5292 - val_accuracy: 0.8688
# Epoch 77/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6380 - accuracy: 0.8360 - val_loss: 0.5474 - val_accuracy: 0.8638
# Epoch 78/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.6029 - accuracy: 0.8422 - val_loss: 0.5230 - val_accuracy: 0.8675
# Epoch 79/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.5745 - accuracy: 0.8480 - val_loss: 0.4938 - val_accuracy: 0.8679
# Epoch 80/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.5414 - accuracy: 0.8511 - val_loss: 0.4680 - val_accuracy: 0.8696
# Epoch 81/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.5372 - accuracy: 0.8507 - val_loss: 0.4849 - val_accuracy: 0.8688
# Epoch 82/1000
# 377/377 [==============================] - 9s 25ms/step - loss: 0.5381 - accuracy: 0.8513 - val_loss: 0.4770 - val_accuracy: 0.8713
# Epoch 83/1000
# 377/377 [==============================] - 9s 24ms/step - loss: 0.5334 - accuracy: 0.8496 - val_loss: 0.4843 - val_accuracy: 0.8708

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
seed_text = "I've got a good feeling about this"
next_words = 10

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list],maxlen=max_sequence_len-1,padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    seed_text += " " + output_word
print(seed_text)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# I've got a good feeling about this oak near my auld rigadoo in the rest by spancil

# %%
# Define a unique model name based on the current timestamp
model_name = f'model_{str(datetime.now().strftime("%Y%m%d_%H%M%S"))}.h5'
model_path = os.path.join('Bi-LSTMModelsT', model_name)
# Save the trained model
model.save(model_path)
print(f"Trained model saved at: {model_path}")
# Out:
# Trained model saved at: Bi-LSTMModelsT\model_20230608_192510.h5

# %%
# Save the tokenizer with a unique filename
import pickle
tokenizer_file = f'tokenizer_{str(datetime.now().strftime("%Y%m%d_%H%M%S"))}.pkl'
os.makedirs('Bi-LSTM TokenizerT')
tokenizer_path = os.path.join('Bi-LSTM TokenizerT', tokenizer_file)

# Save the tokenizer
with open(tokenizer_path, 'wb') as f:
    pickle.dump(tokenizer, f)
print(f"Tokenizer saved at: {model_path}")
# Out:
# Tokenizer saved at: Bi-LSTMModelsT\model_20230608_192510.h5
